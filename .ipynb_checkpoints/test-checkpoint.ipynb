# %%
import pandas as pd
from IPython.display import display

# Excel file path
file_path = 'C:\Ayman\VS-servicenowreports\year\incident2023.xlsx'  # Update with your file path

# Read the Excel file into a DataFrame
df = pd.read_excel(file_path)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3103 entries, 0 to 3102
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Number                           3103 non-null   object
#  1   Diagnosed Entity                 3103 non-null   object
#  2   Reported Entity                  3103 non-null   object
#  3   Assigned to                      3095 non-null   object
#  4   Assignment group                 3103 non-null   object
#  5   Service Name                     3103 non-null   object
#  6   Service Code                     2882 non-null   object
#  7   Incident State                   3103 non-null   object
#  8   Sub State                        572 non-null    object
#  9   Previous State                   3016 non-null   object
#  10  Priority                         3103 non-null   object
# ...

# %%
df.describe()
# Out:
#                              Created                       Resolved  \
# count                           3103                           3072
# mean   2023-06-20 14:31:27.877537536  2023-06-29 09:49:24.815429632
# min              2023-01-01 09:41:20            2023-01-03 11:47:22
# 25%       2023-05-09 12:01:05.500000            2023-05-14 19:33:41
# 50%              2023-07-16 09:51:48            2023-07-25 12:20:00
# 75%              2023-08-11 10:29:39     2023-08-28 11:26:21.500000
# max              2023-09-25 13:39:32            2023-09-25 16:21:13
# std                              NaN                            NaN
#
#        Resolve time  Business resolve time  Reopen count
# count  3.079000e+03           3.079000e+03   3103.000000
# mean   8.316048e+05           1.951883e+05      0.062198
# min    7.500000e+01           0.000000e+00      0.000000
# 25%    1.973250e+05           5.760000e+04      0.000000
# 50%    5.475080e+05           1.258520e+05      0.000000
# ...

# %%
df.head()
# Out:
#        Number Diagnosed Entity Reported Entity     Assigned to  \
# 0  INC0031593              DPM            ADDA  Mahitab Hussan
# 1  INC0031639              DPM            ADDA  Mahitab Hussan
# 2  INC0031655              DPM            ADDA  Mahitab Hussan
# 3  INC0031662              DMT            ADDA  Mahitab Hussan
# 4  INC0031712              DPM            ADDA     Hani Husain
#
#          Assignment group                                       Service Name  \
# 0  DMT - DARI Services L3               Request for a Lease Contract Renewal
# 1  DMT - DARI Services L3                          Request an Ownership Deed
# 2  DMT - DARI Services L3                              Request for Site Plan
# 3    DMT - ITC L3 Support                    Request a Valuation Certificate
# 4    DMT - ITC L2 Support  Request Issuance or Renewal of a Survey Indivi...
#
#   Service Code Incident State                  Sub State Previous State  ...  \
# ...

# %%
df.all()
# Out:
# C:\Users\AymanAwad\AppData\Local\Temp\ipykernel_16844\1858146637.py:1: FutureWarning: 'all' with datetime64 dtypes is deprecated and will raise in a future version. Use (obj != pd.Timestamp(0)).all() instead.
#   df.all()
# Number                              True
# Diagnosed Entity                    True
# Reported Entity                     True
# Assigned to                         True
# Assignment group                    True
# Service Name                        True
# Service Code                        True
# Incident State                      True
# Sub State                           True
# Previous State                      True
# Priority                            True
# Created                             True
# Resolved                            True
# Resolved by                         True
# Resolution Breached on Assignee     True
# Resolution Breached on Group        True
# Resolution SLA                     False
# Resolve time                        True
# ...

# %%
import pandas as pd

# Load the provided DataFrame
# Replace df with the actual DataFrame
# df = ... (the DataFrame you've provided)

# 1. Data Exploration
print("First few rows of the DataFrame:")
print(df.head())

print("\nMissing values per column:")
print(df.isnull().sum())

# 2. Summary Statistics
summary_stats = df[['Resolve time', 'Business resolve time', 'Reopen count']].describe()
print("\nSummary Statistics for Relevant Numerical Columns:")
print(summary_stats)
# Out:
# First few rows of the DataFrame:
#        Number Diagnosed Entity Reported Entity     Assigned to  \
# 0  INC0031593              DPM            ADDA  Mahitab Hussan
# 1  INC0031639              DPM            ADDA  Mahitab Hussan
# 2  INC0031655              DPM            ADDA  Mahitab Hussan
# 3  INC0031662              DMT            ADDA  Mahitab Hussan
# 4  INC0031712              DPM            ADDA     Hani Husain
#
#          Assignment group                                       Service Name  \
# 0  DMT - DARI Services L3               Request for a Lease Contract Renewal
# 1  DMT - DARI Services L3                          Request an Ownership Deed
# 2  DMT - DARI Services L3                              Request for Site Plan
# 3    DMT - ITC L3 Support                    Request a Valuation Certificate
# 4    DMT - ITC L2 Support  Request Issuance or Renewal of a Survey Indivi...
#
#   Service Code Incident State                  Sub State Previous State  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3103 entries, 0 to 3102
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Number                           3103 non-null   object
#  1   Diagnosed Entity                 3103 non-null   object
#  2   Reported Entity                  3103 non-null   object
#  3   Assigned to                      3095 non-null   object
#  4   Assignment group                 3103 non-null   object
#  5   Service Name                     3103 non-null   object
#  6   Service Code                     2882 non-null   object
#  7   Incident State                   3103 non-null   object
#  8   Sub State                        572 non-null    object
#  9   Previous State                   3016 non-null   object
#  10  Priority                         3103 non-null   object
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# Set a style for seaborn
sns.set_style('whitegrid')

# Set a color palette with distinct colors
palette = sns.color_palette("Set1", 4)

# Create a figure with subplots for daily, weekly, and monthly trends
fig, axes = plt.subplots(3, 1, figsize=(16, 18), sharex=True)

# Plot the number of created and resolved incidents over time (daily)
axes[0].bar(created_counts_per_day.index, created_counts_per_day, width=0.6, label='Created Incidents', color=palette[0], alpha=0.9)
axes[0].plot(resolved_counts_per_day.index, resolved_counts_per_day, label='Resolved Incidents', color=palette[1], marker='o', markersize=6, linestyle='-', linewidth=2)
axes[0].axhline(y=max(created_counts_per_day), color=palette[0], linestyle='--', label=f'Max Created Incidents ({max(created_counts_per_day)})', linewidth=2)
axes[0].axhline(y=max(resolved_counts_per_day), color=palette[1], linestyle='--', label=f'Max Resolved Incidents ({max(resolved_counts_per_day)})', linewidth=2)
axes[0].set_title('Daily Created vs Resolved Incidents', fontsize=18)
axes[0].set_ylabel('Number of Incidents', fontsize=14)
axes[0].legend(fontsize=12)
axes[0].grid(axis='y')

# Adding numeric data labels for the maximum points
axes[0].annotate(f'Max Created: {max(created_counts_per_day)}', xy=(created_counts_per_day.idxmax(), max(created_counts_per_day)), 
                 xytext=(20, -20), textcoords='offset points', fontsize=12,
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

axes[0].annotate(f'Max Resolved: {max(resolved_counts_per_day)}', xy=(resolved_counts_per_day.idxmax(), max(resolved_counts_per_day)), 
                 xytext=(-20, 20), textcoords='offset points', fontsize=12,
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

# Plot the number of created and resolved incidents over time (weekly)
axes[1].plot(created_counts_per_week.index, created_counts_per_week, label='Created Incidents', color=palette[0], marker='o', markersize=10, linestyle='-', linewidth=2)
axes[1].plot(resolved_counts_per_week.index, resolved_counts_per_week, label='Resolved Incidents', color=palette[1], marker='o', markersize=10, linestyle='-', linewidth=2)
axes[1].axhline(y=max(created_counts_per_week), color=palette[0], linestyle='--', label=f'Max Created Incidents ({max(created_counts_per_week)})', linewidth=2)
axes[1].axhline(y=max(resolved_counts_per_week), color=palette[1], linestyle='--', label=f'Max Resolved Incidents ({max(resolved_counts_per_week)})', linewidth=2)
axes[1].set_title('Weekly Created vs Resolved Incidents', fontsize=18)
axes[1].set_ylabel('Number of Incidents', fontsize=14)
axes[1].legend(fontsize=12)
axes[1].grid(axis='y')

# Adding numeric data labels for the maximum points
axes[1].annotate(f'Max Created: {max(created_counts_per_week)}', xy=(created_counts_per_week.idxmax(), max(created_counts_per_week)), 
                 xytext=(20, -20), textcoords='offset points', fontsize=12,
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

axes[1].annotate(f'Max Resolved: {max(resolved_counts_per_week)}', xy=(resolved_counts_per_week.idxmax(), max(resolved_counts_per_week)), 
                 xytext=(-20, 20), textcoords='offset points', fontsize=12,
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

# Plot the number of created and resolved incidents over time (monthly)
axes[2].plot(created_counts_per_month.index, created_counts_per_month, label='Created Incidents', color=palette[0], marker='o', markersize=12, linestyle='-', linewidth=2)
axes[2].plot(resolved_counts_per_month.index, resolved_counts_per_month, label='Resolved Incidents', color=palette[1], marker='o', markersize=12, linestyle='-', linewidth=2)
axes[2].axhline(y=max(created_counts_per_month), color=palette[0], linestyle='--', label=f'Max Created Incidents ({max(created_counts_per_month)})', linewidth=2)
axes[2].axhline(y=max(resolved_counts_per_month), color=palette[1], linestyle='--', label=f'Max Resolved Incidents ({max(resolved_counts_per_month)})', linewidth=2)
axes[2].set_title('Monthly Created vs Resolved Incidents', fontsize=18)
axes[2].set_xlabel('Date', fontsize=14)
axes[2].set_ylabel('Number of Incidents', fontsize=14)
axes[2].legend(fontsize=12)
axes[2].grid(axis='y')

# Adding numeric data labels for the maximum points
axes[2].annotate(f'Max Created: {max(created_counts_per_month)}', xy=(created_counts_per_month.idxmax(), max(created_counts_per_month)), 
                 xytext=(20, -20), textcoords='offset points', fontsize=12,
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

axes[2].annotate(f'Max Resolved: {max(resolved_counts_per_month)}', xy=(resolved_counts_per_month.idxmax(), max(resolved_counts_per_month)), 
                 xytext=(-20, 20), textcoords='offset points', fontsize=12,
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

# Add an overall title and adjust spacing
fig.suptitle('Incident Trends Over Time (Jan 1 to Sep 25)', fontsize=22)
plt.subplots_adjust(hspace=0.4)

# Show the plots
plt.xticks(fontsize=12, rotation=45)
plt.tight_layout()
plt.show()

# Summary
print("Summary:")
print("The visualization presents trends of incidents over time from January 1 to September 25, focusing on daily, weekly, and monthly perspectives:")
print("1. The first plot displays the daily trend of created vs. resolved incidents. The solid bars represent daily created incidents, and the line graph represents daily resolved incidents. The maximum values for both created and resolved incidents are highlighted.")
print("2. The second plot shows the weekly trend of created vs. resolved incidents. Each point represents a week's count of incidents. The maximum values for created and resolved incidents within a week are highlighted.")
print("3. The third plot illustrates the monthly trend of created vs. resolved incidents. Each point represents a month's count of incidents. The maximum values for created and resolved incidents within a month are highlighted.")
# Out:
# Summary:
# The visualization presents trends of incidents over time from January 1 to September 25, focusing on daily, weekly, and monthly perspectives:
# 1. The first plot displays the daily trend of created vs. resolved incidents. The solid bars represent daily created incidents, and the line graph represents daily resolved incidents. The maximum values for both created and resolved incidents are highlighted.
# 2. The second plot shows the weekly trend of created vs. resolved incidents. Each point represents a week's count of incidents. The maximum values for created and resolved incidents within a week are highlighted.
# 3. The third plot illustrates the monthly trend of created vs. resolved incidents. Each point represents a month's count of incidents. The maximum values for created and resolved incidents within a month are highlighted.

# %%
import seaborn as sns

# Set a style for seaborn
sns.set_style('whitegrid')

# Set a color palette with distinct colors
palette = sns.color_palette("Set1", 4)

# Create a figure with subplots for daily, weekly, and monthly trends
fig, axes = plt.subplots(3, 1, figsize=(16, 18), sharex=True)

# Plot the number of created and resolved incidents over time (daily)
axes[0].bar(created_counts_per_day.index, created_counts_per_day, width=0.6, label='Created Incidents', color=palette[0], alpha=0.9)
axes[0].plot(resolved_counts_per_day.index, resolved_counts_per_day, label='Resolved Incidents', color=palette[1], marker='o', markersize=6, linestyle='-', linewidth=2)
axes[0].axhline(y=max(created_counts_per_day), color=palette[0], linestyle='--', label=f'Max Created Incidents ({max(created_counts_per_day)})', linewidth=2)
axes[0].axhline(y=max(resolved_counts_per_day), color=palette[1], linestyle='--', label=f'Max Resolved Incidents ({max(resolved_counts_per_day)})', linewidth=2)
axes[0].set_title('Daily Created vs Resolved Incidents', fontsize=18)
axes[0].set_ylabel('Number of Incidents', fontsize=14)
axes[0].legend(fontsize=12)
axes[0].grid(axis='y')

# Adding numeric data labels for the maximum points
axes[0].annotate(f'Max Created: {max(created_counts_per_day)}', xy=(created_counts_per_day.idxmax(), max(created_counts_per_day)), 
                 xytext=(20, -20), textcoords='offset points', fontsize=12,
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

axes[0].annotate(f'Max Resolved: {max(resolved_counts_per_day)}', xy=(resolved_counts_per_day.idxmax(), max(resolved_counts_per_day)), 
                 xytext=(-20, 20), textcoords='offset points', fontsize=12,
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

# Plot the number of created and resolved incidents over time (weekly)
axes[1].plot(created_counts_per_week.index, created_counts_per_week, label='Created Incidents', color=palette[0], marker='o', markersize=10, linestyle='-', linewidth=2)
axes[1].plot(resolved_counts_per_week.index, resolved_counts_per_week, label='Resolved Incidents', color=palette[1], marker='o', markersize=10, linestyle='-', linewidth=2)
axes[1].axhline(y=max(created_counts_per_week), color=palette[0], linestyle='--', label=f'Max Created Incidents ({max(created_counts_per_week)})', linewidth=2)
axes[1].axhline(y=max(resolved_counts_per_week), color=palette[1], linestyle='--', label=f'Max Resolved Incidents ({max(resolved_counts_per_week)})', linewidth=2)
axes[1].set_title('Weekly Created vs Resolved Incidents', fontsize=18)
axes[1].set_ylabel('Number of Incidents', fontsize=14)
axes[1].legend(fontsize=12)
axes[1].grid(axis='y')

# Adding numeric data labels for the maximum points
axes[1].annotate(f'Max Created: {max(created_counts_per_week)}', xy=(created_counts_per_week.idxmax(), max(created_counts_per_week)), 
                 xytext=(20, -20), textcoords='offset points', fontsize=12,
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

axes[1].annotate(f'Max Resolved: {max(resolved_counts_per_week)}', xy=(resolved_counts_per_week.idxmax(), max(resolved_counts_per_week)), 
                 xytext=(-20, 20), textcoords='offset points', fontsize=12,
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

# Plot the number of created and resolved incidents over time (monthly)
axes[2].plot(created_counts_per_month.index, created_counts_per_month, label='Created Incidents', color=palette[0], marker='o', markersize=12, linestyle='-', linewidth=2)
axes[2].plot(resolved_counts_per_month.index, resolved_counts_per_month, label='Resolved Incidents', color=palette[1], marker='o', markersize=12, linestyle='-', linewidth=2)
axes[2].axhline(y=max(created_counts_per_month), color=palette[0], linestyle='--', label=f'Max Created Incidents ({max(created_counts_per_month)})', linewidth=2)
axes[2].axhline(y=max(resolved_counts_per_month), color=palette[1], linestyle='--', label=f'Max Resolved Incidents ({max(resolved_counts_per_month)})', linewidth=2)
axes[2].set_title('Monthly Created vs Resolved Incidents', fontsize=18)
axes[2].set_xlabel('Date', fontsize=14)
axes[2].set_ylabel('Number of Incidents', fontsize=14)
axes[2].legend(fontsize=12)
axes[2].grid(axis='y')

# Adding numeric data labels for the maximum points
axes[2].annotate(f'Max Created: {max(created_counts_per_month)}', xy=(created_counts_per_month.idxmax(), max(created_counts_per_month)), 
                 xytext=(20, -20), textcoords='offset points', fontsize=12,
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

axes[2].annotate(f'Max Resolved: {max(resolved_counts_per_month)}', xy=(resolved_counts_per_month.idxmax(), max(resolved_counts_per_month)), 
                 xytext=(-20, 20), textcoords='offset points', fontsize=12,
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

# Add an overall title and adjust spacing
fig.suptitle('Incident Trends Over Time (Jan 1 to Sep 25)', fontsize=22)
plt.subplots_adjust(hspace=0.4)

# Show the plots
plt.xticks(fontsize=12, rotation=45)
plt.tight_layout()
plt.show()

# Save the figure as an image
fig.savefig('incident_trends_over_time.png')

# Summary
print("Summary:")
print("The visualization provides a comprehensive view of incident trends from January 1 to September 25, focusing on daily, weekly, and monthly perspectives:")

print("\n1. Daily Trend (Top Plot):")
print("The top plot presents the daily trend of created vs. resolved incidents. The solid bars represent the number of incidents created each day, while the line graph represents the number of incidents resolved. The maximum values for both created and resolved incidents are highlighted. This view helps in understanding the daily fluctuations and identifying high-activity periods.")

print("\nInsights:")
print("- On", created_counts_per_day.idxmax().strftime('%Y-%m-%d') + ",", "the maximum number of incidents were created, reaching", max(created_counts_per_day), "incidents.")
print("- On the same day,", resolved_counts_per_day.idxmax().strftime('%Y-%m-%d') + ",", "the highest number of incidents were resolved, totaling", max(resolved_counts_per_day), "resolved incidents.")

print("\n2. Weekly Trend (Middle Plot):")
print("The middle plot illustrates the weekly trend of created vs. resolved incidents. Each point represents the count of incidents for a week. The maximum values for created and resolved incidents within a week are highlighted. This view aids in identifying weekly patterns and workload distribution.")

print("\nInsights:")
print("- During the week ending on", created_counts_per_week.idxmax().strftime('%Y-%m-%d') + ",", "the highest number of incidents were created within a week, reaching", max(created_counts_per_week), "incidents.")
print("- In the same week ending on", resolved_counts_per_week.idxmax().strftime('%Y-%m-%d') + ",", "the most incidents were resolved, totaling", max(resolved_counts_per_week), "resolved incidents.")

print("\n3. Monthly Trend (Bottom Plot):")
print("The bottom plot showcases the monthly trend of created vs. resolved incidents. Each point represents the count of incidents for a month. The maximum values for created and resolved incidents within a month are highlighted. This view enables understanding monthly trends, facilitating long-term planning and resource allocation.")

print("\nInsights:")
print("- In", created_counts_per_month.idxmax().strftime('%B %Y') + ",", "the highest number of incidents were created in a month, totaling", max(created_counts_per_month), "incidents.")
print("- In the same month,", resolved_counts_per_month.idxmax().strftime('%B %Y') + ",", "the most incidents were resolved, reaching", max(resolved_counts_per_month), "resolved incidents.")

print("\nOverall Insights:")
print("- The data suggests a correlation between incident creation and resolution trends. High incident creation periods often coincide with high incident resolution periods, implying effective incident management.")
print("- Identifying peak activity periods is crucial for resource allocation, ensuring adequate support during high-demand times.")
print("- Tracking weekly and monthly trends helps in understanding recurring patterns, assisting in workload distribution and long-term planning.")
print("- The visualization provides actionable insights for optimizing incident management processes and enhancing service quality based on historical trends.")
# Out:
# Summary:
# The visualization provides a comprehensive view of incident trends from January 1 to September 25, focusing on daily, weekly, and monthly perspectives:
#
# 1. Daily Trend (Top Plot):
# The top plot presents the daily trend of created vs. resolved incidents. The solid bars represent the number of incidents created each day, while the line graph represents the number of incidents resolved. The maximum values for both created and resolved incidents are highlighted. This view helps in understanding the daily fluctuations and identifying high-activity periods.
#
# Insights:
# - On 2023-07-17, the maximum number of incidents were created, reaching 66 incidents.
# - On the same day, 2023-09-04, the highest number of incidents were resolved, totaling 122 resolved incidents.
#
# 2. Weekly Trend (Middle Plot):
# ...

# %%
# Summary
print("Summary:")
print("The visualization provides a comprehensive view of incident trends from January 1 to September 25, focusing on daily, weekly, and monthly perspectives:")

print("\n1. Daily Trend (Top Plot):")
print("The top plot presents the daily trend of created vs. resolved incidents. The solid bars represent the number of incidents created each day, while the line graph represents the number of incidents resolved. The maximum values for both created and resolved incidents are highlighted. This view helps in understanding the daily fluctuations and identifying high-activity periods.")

print("\nInsights:")
print("- On", created_counts_per_day.idxmax().strftime('%Y-%m-%d') + ",", "the maximum number of incidents were created, reaching", max(created_counts_per_day), "incidents.")
print("- On the same day,", resolved_counts_per_day.idxmax().strftime('%Y-%m-%d') + ",", "the highest number of incidents were resolved, totaling", max(resolved_counts_per_day), "resolved incidents.")

print("\n2. Weekly Trend (Middle Plot):")
print("The middle plot illustrates the weekly trend of created vs. resolved incidents. Each point represents the count of incidents for a week. The maximum values for created and resolved incidents within a week are highlighted. This view aids in identifying weekly patterns and workload distribution.")

print("\nInsights:")
print("- During the week ending on", created_counts_per_week.idxmax().strftime('%Y-%m-%d') + ",", "the highest number of incidents were created within a week, reaching", max(created_counts_per_week), "incidents.")
print("- In the same week ending on", resolved_counts_per_week.idxmax().strftime('%Y-%m-%d') + ",", "the most incidents were resolved, totaling", max(resolved_counts_per_week), "resolved incidents.")

print("\n3. Monthly Trend (Bottom Plot):")
print("The bottom plot showcases the monthly trend of created vs. resolved incidents. Each point represents the count of incidents for a month. The maximum values for created and resolved incidents within a month are highlighted. This view enables understanding monthly trends, facilitating long-term planning and resource allocation.")

print("\nInsights:")
print("- In", created_counts_per_month.idxmax().strftime('%B %Y') + ",", "the highest number of incidents were created in a month, totaling", max(created_counts_per_month), "incidents.")
print("- In the same month,", resolved_counts_per_month.idxmax().strftime('%B %Y') + ",", "the most incidents were resolved, reaching", max(resolved_counts_per_month), "resolved incidents.")

print("\nOverall Insights:")
print("- The data suggests a correlation between incident creation and resolution trends. High incident creation periods often coincide with high incident resolution periods, implying effective incident management.")
print("- Identifying peak activity periods is crucial for resource allocation, ensuring adequate support during high-demand times.")
print("- Tracking weekly and monthly trends helps in understanding recurring patterns, assisting in workload distribution and long-term planning.")
print("- The visualization provides actionable insights for optimizing incident management processes and enhancing service quality based on historical trends.")
# Out:
# Summary:
# The visualization provides a comprehensive view of incident trends from January 1 to September 25, focusing on daily, weekly, and monthly perspectives:
#
# 1. Daily Trend (Top Plot):
# The top plot presents the daily trend of created vs. resolved incidents. The solid bars represent the number of incidents created each day, while the line graph represents the number of incidents resolved. The maximum values for both created and resolved incidents are highlighted. This view helps in understanding the daily fluctuations and identifying high-activity periods.
#
# Insights:
# - On 2023-07-17, the maximum number of incidents were created, reaching 66 incidents.
# - On the same day, 2023-09-04, the highest number of incidents were resolved, totaling 122 resolved incidents.
#
# 2. Weekly Trend (Middle Plot):
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3103 entries, 0 to 3102
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Number                           3103 non-null   object
#  1   Diagnosed Entity                 3103 non-null   object
#  2   Reported Entity                  3103 non-null   object
#  3   Assigned to                      3095 non-null   object
#  4   Assignment group                 3103 non-null   object
#  5   Service Name                     3103 non-null   object
#  6   Service Code                     2882 non-null   object
#  7   Incident State                   3103 non-null   object
#  8   Sub State                        572 non-null    object
#  9   Previous State                   3016 non-null   object
#  10  Priority                         3103 non-null   object
# ...

# %%
df.describe()
# Out:
#                              Created                       Resolved  \
# count                           3103                           3072
# mean   2023-06-20 14:31:27.877537536  2023-06-29 09:49:24.815429632
# min              2023-01-01 09:41:20            2023-01-03 11:47:22
# 25%       2023-05-09 12:01:05.500000            2023-05-14 19:33:41
# 50%              2023-07-16 09:51:48            2023-07-25 12:20:00
# 75%              2023-08-11 10:29:39     2023-08-28 11:26:21.500000
# max              2023-09-25 13:39:32            2023-09-25 16:21:13
# std                              NaN                            NaN
#
#        Resolve time  Business resolve time  Reopen count
# count  3.079000e+03           3.079000e+03   3103.000000
# mean   8.316048e+05           1.951883e+05      0.062198
# min    7.500000e+01           0.000000e+00      0.000000
# 25%    1.973250e+05           5.760000e+04      0.000000
# 50%    5.475080e+05           1.258520e+05      0.000000
# ...

# %%
df.head()
# Out:
#        Number Diagnosed Entity Reported Entity     Assigned to  \
# 0  INC0031593              DPM            ADDA  Mahitab Hussan
# 1  INC0031639              DPM            ADDA  Mahitab Hussan
# 2  INC0031655              DPM            ADDA  Mahitab Hussan
# 3  INC0031662              DMT            ADDA  Mahitab Hussan
# 4  INC0031712              DPM            ADDA     Hani Husain
#
#          Assignment group                                       Service Name  \
# 0  DMT - DARI Services L3               Request for a Lease Contract Renewal
# 1  DMT - DARI Services L3                          Request an Ownership Deed
# 2  DMT - DARI Services L3                              Request for Site Plan
# 3    DMT - ITC L3 Support                    Request a Valuation Certificate
# 4    DMT - ITC L2 Support  Request Issuance or Renewal of a Survey Indivi...
#
#   Service Code Incident State                  Sub State Previous State  ...  \
# ...

# %%
import numpy as np

# Convert seconds to 'DD HH MM' format
def seconds_to_dd_hh_mm(seconds):
    if np.isnan(seconds):
        return 'N/A'
    
    days = seconds // (3600 * 24)
    remaining_seconds = seconds % (3600 * 24)
    hours = remaining_seconds // 3600
    remaining_seconds %= 3600
    minutes = remaining_seconds // 60
    return f'{int(days)}d {int(hours)}h {int(minutes)}m'

# Apply the conversion to the DataFrame
df['Resolve time (DD HH MM)'] = df['Resolve time'].apply(seconds_to_dd_hh_mm)
df['Business resolve time (DD HH MM)'] = df['Business resolve time'].apply(seconds_to_dd_hh_mm)

# %%
import numpy as np

# Function to convert seconds to 'days hours minutes' format
def seconds_to_dd_hh_mm(seconds):
    days = seconds // (24 * 3600)
    remaining_seconds = seconds % (24 * 3600)
    hours = remaining_seconds // 3600
    remaining_seconds %= 3600
    minutes = remaining_seconds // 60
    return f'{int(days)}d {int(hours)}h {int(minutes)}m' if days > 0 else f'{int(hours)}h {int(minutes)}m'

# Convert minimum and maximum resolve time to 'days hours minutes' format
min_resolve_time_dd_hh_mm = seconds_to_dd_hh_mm(df['Resolve time'].min())
max_resolve_time_dd_hh_mm = seconds_to_dd_hh_mm(df['Resolve time'].max())

# Comment explaining the difference between 'Resolve time' and 'Business resolve time'
comment = """
'Resolve time' represents the total time taken to resolve an incident, including non-business hours.
'Business resolve time' considers only business hours for incident resolution, excluding non-business hours.
"""

# Print the results
print("Minimum Resolve Time (DD HH MM):", min_resolve_time_dd_hh_mm)
print("Maximum Resolve Time (DD HH MM):", max_resolve_time_dd_hh_mm)
print(comment)
# Out:
# Minimum Resolve Time (DD HH MM): 0h 1m
# Maximum Resolve Time (DD HH MM): 92d 23h 14m
#
# 'Resolve time' represents the total time taken to resolve an incident, including non-business hours.
# 'Business resolve time' considers only business hours for incident resolution, excluding non-business hours.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3103 entries, 0 to 3102
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Number                           3103 non-null   object
#  1   Diagnosed Entity                 3103 non-null   object
#  2   Reported Entity                  3103 non-null   object
#  3   Assigned to                      3095 non-null   object
#  4   Assignment group                 3103 non-null   object
#  5   Service Name                     3103 non-null   object
#  6   Service Code                     2882 non-null   object
#  7   Incident State                   3103 non-null   object
#  8   Sub State                        572 non-null    object
#  9   Previous State                   3016 non-null   object
#  10  Priority                         3103 non-null   object
# ...

# %%
# Count of True and False in 'Resolution SLA'
sla_counts = df['Resolution SLA'].value_counts()

# Extract counts
true_count = sla_counts[True] if True in sla_counts else 0
false_count = sla_counts[False] if False in sla_counts else 0

true_count, false_count
# Out:
# (1352, 1751)

# %%
# Select columns that can be converted to numerical values
numerical_columns = df.select_dtypes(include=['int64', 'float64'])

# Convert 'Resolve time' and 'Business resolve time' to numeric (seconds)
df['Resolve time'] = pd.to_numeric(df['Resolve time'], errors='coerce')
df['Business resolve time'] = pd.to_numeric(df['Business resolve time'], errors='coerce')

# Convert datetime columns to numeric (in seconds)
df['Created'] = (df['Created'] - df['Created'].min()).dt.total_seconds()
df['Resolved'] = (df['Resolved'] - df['Created']).dt.total_seconds()

# Convert 'Resolution SLA' to numerical (True as 1, False as 0)
df['Resolution SLA'] = df['Resolution SLA'].astype(int)

# Display the updated DataFrame
print(df.info())
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[174], line 10
#       8 # Convert datetime columns to numeric (in seconds)
#       9 df['Created'] = (df['Created'] - df['Created'].min()).dt.total_seconds()
# ---> 10 df['Resolved'] = (df['Resolved'] - df['Created']).dt.total_seconds()
#      12 # Convert 'Resolution SLA' to numerical (True as 1, False as 0)
#      13 df['Resolution SLA'] = df['Resolution SLA'].astype(int)
#
# File C:\Ayman\VS-servicenowreports\SN\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File C:\Ayman\VS-servicenowreports\SN\Lib\site-packages\pandas\core\arraylike.py:194, in OpsMixin.__sub__(self, other)
#     192 @unpack_zerodim_and_defer("__sub__")
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3103 entries, 0 to 3102
# Data columns (total 28 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Number                            3103 non-null   object
#  1   Diagnosed Entity                  3103 non-null   object
#  2   Reported Entity                   3103 non-null   object
#  3   Assigned to                       3095 non-null   object
#  4   Assignment group                  3103 non-null   object
#  5   Service Name                      3103 non-null   object
#  6   Service Code                      2882 non-null   object
#  7   Incident State                    3103 non-null   object
#  8   Sub State                         572 non-null    object
#  9   Previous State                    3016 non-null   object
#  10  Priority                          3103 non-null   object
# ...

# %%
df.head()
df.describe()
# Out:
#             Created                       Resolved  Resolve time  \
# count  3.103000e+03                           3072  3.079000e+03
# mean   1.470541e+07  2023-06-29 09:49:24.815429632  8.316048e+05
# min    0.000000e+00            2023-01-03 11:47:22  7.500000e+01
# 25%    1.106759e+07            2023-05-14 19:33:41  1.973250e+05
# 50%    1.693503e+07            2023-07-25 12:20:00  5.475080e+05
# 75%    1.918370e+07     2023-08-28 11:26:21.500000  1.151060e+06
# max    2.308309e+07            2023-09-25 16:21:13  8.032463e+06
# std    6.115120e+06                            NaN  8.754738e+05
#
#        Business resolve time  Reopen count
# count           3.079000e+03   3103.000000
# mean            1.951883e+05      0.062198
# min             0.000000e+00      0.000000
# 25%             5.760000e+04      0.000000
# 50%             1.258520e+05      0.000000
# 75%             2.624335e+05      0.000000
# max             1.929600e+06      5.000000
# ...

# %%
df.head()
# Out:
#        Number Diagnosed Entity Reported Entity     Assigned to  \
# 0  INC0031593              DPM            ADDA  Mahitab Hussan
# 1  INC0031639              DPM            ADDA  Mahitab Hussan
# 2  INC0031655              DPM            ADDA  Mahitab Hussan
# 3  INC0031662              DMT            ADDA  Mahitab Hussan
# 4  INC0031712              DPM            ADDA     Hani Husain
#
#          Assignment group                                       Service Name  \
# 0  DMT - DARI Services L3               Request for a Lease Contract Renewal
# 1  DMT - DARI Services L3                          Request an Ownership Deed
# 2  DMT - DARI Services L3                              Request for Site Plan
# 3    DMT - ITC L3 Support                    Request a Valuation Certificate
# 4    DMT - ITC L2 Support  Request Issuance or Renewal of a Survey Indivi...
#
#   Service Code Incident State                  Sub State Previous State  ...  \
# ...

# %%
# Convert columns to numerical values
df['Resolve time'] = df['Resolve time'].astype(float)
df['Business resolve time'] = df['Business resolve time'].astype(float)
df['Reopen count'] = df['Reopen count'].astype(float)

# %%
# Calculate correlations
correlations = df[['Resolve time', 'Business resolve time', 'Reopen count']].corr()

# Display the correlation matrix
print("Correlation Matrix:")
print(correlations)
# Out:
# Correlation Matrix:
#                        Resolve time  Business resolve time  Reopen count
# Resolve time               1.000000               0.996676      0.121113
# Business resolve time      0.996676               1.000000      0.123879
# Reopen count               0.121113               0.123879      1.000000

# %%
import seaborn as sns

# Convert columns to numeric where applicable
df['Resolve time'] = pd.to_numeric(df['Resolve time'], errors='coerce')
df['Business resolve time'] = pd.to_numeric(df['Business resolve time'], errors='coerce')

# Extract relevant columns for correlation analysis
selected_columns = ['Service Name', 'Resolve time', 'Business resolve time', 'Created', 'Resolved', 'Priority']
selected_df = df[selected_columns]

# Calculate the correlation matrix
correlation_matrix = selected_df.corr()

# Plot the correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[183], line 12
#       9 selected_df = df[selected_columns]
#      11 # Calculate the correlation matrix
# ---> 12 correlation_matrix = selected_df.corr()
#      14 # Plot the correlation heatmap
#      15 plt.figure(figsize=(10, 8))
#
# File C:\Ayman\VS-servicenowreports\SN\Lib\site-packages\pandas\core\frame.py:10707, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10705 cols = data.columns
#   10706 idx = cols.copy()
# > 10707 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10709 if method == "pearson":
#   10710     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\Ayman\VS-servicenowreports\SN\Lib\site-packages\pandas\core\frame.py:1892, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1890 if dtype is not None:
#    1891     dtype = np.dtype(dtype)
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Select relevant columns
selected_columns = ['Service Name', 'Resolve time', 'Business resolve time', 'Created', 'Resolved', 'Priority']

# Create a DataFrame with selected columns
selected_df = df[selected_columns]

# Convert date columns to numerical (days since the earliest date in the dataset)
date_columns = ['Created', 'Resolved']
earliest_date = df[date_columns].min()
selected_df[date_columns] = (selected_df[date_columns] - earliest_date).apply(lambda x: x.dt.days)

# Convert Priority to numerical
priority_mapping = {'Low': 1, 'Medium': 2, 'High': 3, 'Critical': 4}
selected_df['Priority'] = selected_df['Priority'].map(priority_mapping)

# Calculate the correlation matrix
correlation_matrix = selected_df.corr()

# Plot the correlation heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
